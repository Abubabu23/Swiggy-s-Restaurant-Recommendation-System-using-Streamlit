# %%
import pandas as pd


##Load data

df = pd.read_csv(r"C:\Users\Abuthahir\project\Swiggy Food Recommentation System\data\swiggy.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148541 entries, 0 to 148540
# Data columns (total 11 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   id            148541 non-null  int64
#  1   name          148455 non-null  object
#  2   city          148541 non-null  object
#  3   rating        148455 non-null  object
#  4   rating_count  148455 non-null  object
#  5   cost          148410 non-null  object
#  6   cuisine       148442 non-null  object
#  7   lic_no        148312 non-null  object
#  8   link          148541 non-null  object
#  9   address       148455 non-null  object
#  10  menu          148541 non-null  object
# dtypes: int64(1), object(10)
# memory usage: 12.5+ MB

# %%
df.isnull().sum()
# Out:
# id              0
# name            0
# city            0
# rating          0
# rating_count    0
# cost            0
# cuisine         0
# lic_no          0
# link            0
# address         0
# menu            0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
selected_cities = [
    'Abohar',
    'Adilabad',
    'Adityapur',
    'Adoni',
    'Agartala',
    'Agra',
    'Vastrapur,Ahmedabad',
    'GOTA,Ahmedabad',
    'Paldi & Ambawadi,Ahmedabad',
    'Ghatlodia,AhmedabadVellore'
]

# %%
df_filtered = df[df['city'].isin(selected_cities)]

# %%
df_filtered['city'].unique()
# Out:
# array(['Abohar', 'Adilabad', 'Adityapur', 'Adoni', 'Agartala', 'Agra',
#        'Vastrapur,Ahmedabad', 'GOTA,Ahmedabad',
#        'Paldi & Ambawadi,Ahmedabad'], dtype=object)

# %%
df_filtered.to_csv(
    r"C:\Users\Abuthahir\project\Swiggy Food Recommentation System\data\cleaned_data.csv",
    index=False
)

print(" cleaned_data.csv saved")
# Out:
#  cleaned_data.csv saved
